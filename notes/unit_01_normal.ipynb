# %% [markdown]
# ```Text
# Qt / PyQt / PySide
# 负责：
# - QApplication
# - QMainWindow / QWidget
# - 布局
# - 菜单栏、工具栏
# - 按钮、表格、输入框
# - 信号槽
# - 线程
# - 定时器
#
# pyqtgraph
# 负责：
# - PlotWidget
# - GraphicsLayoutWidget
# - PlotItem
# - PlotDataItem
# - ImageItem
# - BarGraphItem
# - ErrorBarItem
# - InfiniteLine
# - ROI
# - 高性能实时绘图
# ```
